# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Kshitij\\Downloads\\F1_CICD\\F1_ML_Ops_CI-CD\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Kshitij\\Downloads\\F1_CICD\\F1_ML_Ops_CI-CD'

# %%
import pandas as pd

# %%
df =pd.read_csv("artifacts/data_ingestion/f1_stint_data_2020_2024.csv") 
df
# Out:
#       Unnamed: 0            EventName  RoundNumber  EventYear        Team  \
# 0              0  Austrian Grand Prix            1       2020    Mercedes
# 1              1  Austrian Grand Prix            1       2020    Mercedes
# 2              2  Austrian Grand Prix            1       2020    Mercedes
# 3              3  Austrian Grand Prix            1       2020     Ferrari
# 4              4  Austrian Grand Prix            1       2020     Ferrari
# ...          ...                  ...          ...        ...         ...
# 2410        2410     Miami Grand Prix            5       2022  AlphaTauri
# 2411        2411     Miami Grand Prix            5       2022  AlphaTauri
# 2412        2412     Miami Grand Prix            5       2022     McLaren
# 2413        2413     Miami Grand Prix            5       2022     McLaren
# 2414        2414     Miami Grand Prix            5       2022  Alfa Romeo
#
#                Driver  GridPosition  FinalPosition Compound  StintLen  ...  \
# ...

# %%
df.info(25)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2415 entries, 0 to 2414
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2415 non-null   int64
#  1   EventName         2415 non-null   object
#  2   RoundNumber       2415 non-null   int64
#  3   EventYear         2415 non-null   int64
#  4   Team              2415 non-null   object
#  5   Driver            2415 non-null   object
#  6   GridPosition      2415 non-null   int64
#  7   FinalPosition     2415 non-null   int64
#  8   Compound          2415 non-null   object
#  9   StintLen          2415 non-null   int64
#  10  CircuitLength     2415 non-null   int64
#  11  DesignedLaps      2415 non-null   int64
#  12  StintStartLap     2415 non-null   float64
#  13  StintEndLap       2415 non-null   float64
#  14  AvgLapTime        2301 non-null   float64
#  15  TrackTemp         2415 non-null   float64
# ...
